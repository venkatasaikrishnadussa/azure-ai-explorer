# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatasaikrishnadussa/azure-ai-explorer/blob/main/AI_102_Analyze_Images_with_Azure_AI_Vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot 2024-09-15 at 9.22.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-15 at 9.24.47 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-15 at 9.29.48 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-09-15 at 9.32.20 PM.png](data:image/png;base64,...)

# %%
URL_ENDPOINT = "https://day02azureai.cognitiveservices.azure.com/"

from google.colab import userdata
API_KEY = userdata.get('AZURE_SUBSCRIPTION_KEY')

# %%
API_KEY
# Out:
# '55f61cfde1ae43f595d33614039f4b6a'

# %%
from PIL import Image

img = Image.open(url"https://github.com/venkatasaikrishnadussa/azure-ai-explorer/blob/main/images/building.jpg")
img.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f2f93e135983> in <cell line: 3>()
#       1 from PIL import Image
#       2
# ----> 3 img = Image.open(url="https://github.com/venkatasaikrishnadussa/azure-ai-explorer/blob/main/images/building.jpg")
#       4 img.show()
#
# TypeError: open() got an unexpected keyword argument 'url'
